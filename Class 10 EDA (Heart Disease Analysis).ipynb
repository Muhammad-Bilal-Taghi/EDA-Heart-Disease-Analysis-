# %% [markdown]
# # Heart Disease Prediction

# %% [markdown]
# #### age: person's age
# #### sex: person's gender
# #### cp: chest pain of four type (1-4)
# #### trestbps: Person's resting blood pressure
# #### chol: Cholestrol lvl
# #### fbs: fasting blood sugar level (0-2)
# #### restegc (0-2)
# ####  thalach : Maximum heart rate achieved
# #### exang : oldpeak
# #### slope
# #### ca
# #### thal (3:Normal, 6:Fixed,7:reversable defect)
# #### target: 0=Np heart disease - 1 = Yes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("heart.csv")

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
sns.set(font_scale=2)
data.hist(figsize=(30,30))
plt.savefig("hist.png")
plt.show()

# %%
data['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
sns.countplot(x='target', data=data)
plt.show()

# %%
data['sex'].value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
sns.countplot(x='sex',data=data)
plt.show()

# %%
data['chol'].value_counts()
# Out:
# 234    21
# 204    21
# 197    19
# 212    18
# 254    17
#        ..
# 257     3
# 259     3
# 262     3
# 290     3
# 564     3
# Name: chol, Length: 152, dtype: int64

# %%
sns.countplot(x='chol',data=data)
plt.show()

# %%
data['exang'].value_counts()
# Out:
# 0    680
# 1    345
# Name: exang, dtype: int64

# %%
sns.countplot(x='exang',data=data )
plt.show()

# %%
data['thal'].value_counts()
# Out:
# 2    544
# 3    410
# 1     64
# 0      7
# Name: thal, dtype: int64

# %%
sns.countplot(x='thal',data=data)
plt.show()

# %%
arr = data.groupby("sex")
arr2 = arr["target"].value_counts()
arr3 = pd.DataFrame(arr2)
arr3.head(n=1000)
# Out:
#             target
# sex target
# 0   1          226
#     0           86
# 1   0          413
#     1          300

# %%
data.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1         226
#      0          86
# 1    0         413
#      1         300
# Name: target, dtype: int64

# %%
sns.countplot(x='sex',hue='target', data=data)
plt.show()

# %%
data.groupby('sex')['oldpeak'].value_counts()
# Out:
# sex  oldpeak
# 0    0.0        111
#      0.6         20
#      0.2         18
#      1.0         18
#      1.4         16
#                ...
# 1    4.4          4
#      5.6          4
#      2.1          3
#      2.9          3
#      3.5          3
# Name: oldpeak, Length: 63, dtype: int64

# %%
sns.countplot(x='sex', hue='oldpeak',data=data)
plt.show()

# %%
data.groupby('age')['target'].value_counts()
# Out:
# age  target
# 29   1          4
# 34   1          6
# 35   1          8
#      0          7
# 37   1          6
#                ..
# 70   1          3
# 71   1         11
# 74   1          3
# 76   1          3
# 77   0          3
# Name: target, Length: 75, dtype: int64

# %%
plt.figure(figsize=(20,12))
sns.countplot(x='age',hue='target',data=data)
plt.savefig('')
plt.show()

# %% [markdown]
#  # Enumarate

# %%
name_list = ['Bilal', 'Junaid', 'Shibly']
list(enumerate(name_list))
# Out:
# [(0, 'Bilal'), (1, 'Junaid'), (2, 'Shibly')]

# %%
a = ['Mango','Apple','Orange']
list(enumerate(a))
# Out:
# [(0, 'Mango'), (1, 'Apple'), (2, 'Orange')]

# %%
b= ['Onioin','Potato','Tomato']
list(enumerate(b))
# Out:
# [(0, 'Onioin'), (1, 'Potato'), (2, 'Tomato')]

# %%
d = 'KomalSaleem'
ans = enumerate(d)
print(list(ans))
# Out:
# [(0, 'K'), (1, 'o'), (2, 'm'), (3, 'a'), (4, 'l'), (5, 'S'), (6, 'a'), (7, 'l'), (8, 'e'), (9, 'e'), (10, 'm')]

# %%
f = 'BilalTaghi'
e = enumerate(f)
print(list(e))
# Out:
# [(0, 'B'), (1, 'i'), (2, 'l'), (3, 'a'), (4, 'l'), (5, 'T'), (6, 'a'), (7, 'g'), (8, 'h'), (9, 'i')]

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
categorical_value=list(data.columns)
print(list(enumerate(categorical_value,1)))
# Out:
# [(1, 'age'), (2, 'sex'), (3, 'cp'), (4, 'trestbps'), (5, 'chol'), (6, 'fbs'), (7, 'restecg'), (8, 'thalach'), (9, 'exang'), (10, 'oldpeak'), (11, 'slope'), (12, 'ca'), (13, 'thal'), (14, 'target')]

# %%
print(list(data.columns))
# Out:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
categorical_value = list(data.columns)
categorical_value.remove('thal')
categorical_value
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'target']

# %% [markdown]
# # f" (formating Script)

# %%
plt.figure(figsize=(35,35))
for i, col in enumerate(categorical_value, 1):
    plt.subplot(4,4,i)
    sns.barplot(x=f"{col}",y='target',data=data)
    plt.ylabel("Possibility of having heart disease")
    plt.savefig("heartdisease.png")
    plt.xlabel(f"{col}")
